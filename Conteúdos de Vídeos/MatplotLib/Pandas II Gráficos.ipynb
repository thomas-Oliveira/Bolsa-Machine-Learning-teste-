# %%
import pandas as pd

# %%
velocidade = [0.1, 17.5, 40, 48, 52, 69, 88]
anos_de_vida = [2, 8, 70, 1.5, 25, 12, 28]
animais = ['caracol', 'porco', 'elefante','coelho', 'girafa', 'coiote', 'cavalo']

df = pd.DataFrame({'velocidade': velocidade, 'anos de vida':anos_de_vida}, index=animais)
df
# Out:
#           anos de vida  velocidade
# caracol            2.0         0.1
# porco              8.0        17.5
# elefante          70.0        40.0
# coelho             1.5        48.0
# girafa            25.0        52.0
# coiote            12.0        69.0
# cavalo            28.0        88.0

# %%
df.plot.scatter(x='velocidade', y='anos de vida')

# %%
df.plot.hist(x='anos de vida', alpha=0.5, color='g')

# %%
df.plot.hist(x='velocidade', alpha=0.5, color='g')

# %%
df.plot(title = 'grafico 1')

# %%
df.plot(subplots= True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fd6c18d5cf8>,
# ...
#       dtype=object)

# %%
df.plot.barh(x='velocidade')

# %%
df.plot.bar(x='velocidade')

# %%
df.plot.barh(subplots = True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fd6c151e630>,
# ...
#       dtype=object)

# %%
df.plot.barh()

# %%
df.plot.bar(stacked= True)

# %%
df.plot.pie(y='velocidade', figsize=(5,5))

# %%
df.plot.pie(subplots=True,figsize=(16,8))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fd6c1592898>,
# ...
#       dtype=object)
